# %%
# Class
class Robot:
# Constructer    
    def __init__(self, name, age, weight):
        self.name = name
        self.age = age
        self.weight = weight
        
    def introduce_Self(self):
        print("my name is " + self.name)
        
# two objects in variables r1 and r2    
robot1 = Robot("Radh",20,70)
robot2 = Robot("Rishov",30,75)     

robot1.introduce_Self()
robot2.introduce_Self()

class Person:
    def __init__(self, n, p, i):
        self.name = n
        self.personality = p
        self.is_sitting = i
        
    def sit_down(self):
        self.is_sitting = "Is siting"
        
    def stand_ip(self):
        self.is_sitting = "Is not siting"
        
    def Informations(self):
        if (self.name == "Alice"):
            print("Her name is " + self.name + " She is " + self.personality + "She is " + self.is_sitting)
        else:
            print("His name is " + self.name + " He is " + self.personality + "He is " + self.is_sitting)   
        
# Objects
Person1 = Person("Alice", "aggressive ", "Is not siting")
Person2 = Person("rad", "talkative ", "Is siting")
# Person1.robot_owned = r2
# Person2.robot_owned = r1
# Person1.robot_owned.introduce_Self()
# Person2.robot_owned.introduce_Self()
Person1.Informations()
Person2.Informations()
# Out:
# my name is Radh
# my name is Rishov
# Her name is Alice She is aggressive She is Is not siting
# His name is rad He is talkative He is Is siting

# %%
class Person:
    def __init__(self, n, p, i):
        self.name = n
        self.personality = p
        self.is_sitting = i
        
    def sit_down(self):
        self.is_sitting = True
        
    def stand_up(self):
        self.is_sitting = False

# Objects

alice = Person("Alice", "aggressive", False)
backy = Person("Backy", "talkative", True)


class Robot:
# Constructer    
    def __init__(self, name, age, weight, master):
        self.master = master
        self.name = name
        self.age = age
        self.weight = weight
        
    def introduce_self(self):
        print("my name is " + self.name)
        
    def introduce_master(self):
        print("my master's name is " + self.master.name)
        
        

r1 = Robot("Radh", 20, 70, alice)
r2 = Robot("Rishov", 30, 75, backy)     

r1.introduce_self()
r1.introduce_master()

r2.introduce_self()
r2.introduce_master()
# Out:
# my name is Radh
# my master's name is Alice
# my name is Rishov
# my master's name is Backy

# %%
class Person:
    def __init__(self, name, personality, sitting_status, gender):
        self.name = name
        self.personality = personality
        self.sitting_status = sitting_status
        self.gender = gender
        
    def sit_down(self):
        self.sitting_status = "is siting"
        
    def stand_ip(self):
        self.sitting_status = "is not siting"
    def Informations(self):
        if(self.gender == "male"):
            representative1 = "his"
        else:
            representative1 = "her"
        if(self.gender == "male"):
            representative2 = "He"
        else:
            representative2 = "She"
        print(representative1 + " name is " + self.name + " and " +  representative2 + " is " + self.personality + representative2 +" is " + self.sitting_status)

p1 = Person("John", "aggressive ", "is not siting", "male")
p2 = Person("Backy", "talkative ", "is siting", "female")

p1.Informations()
p2.Informations()
class Person:
    def __init__(self, name, personality, sitting_status, gender):
        self.name = name
        self.personality = personality
        self.sitting_status = sitting_status
        self.gender = gender
        
    def sit_down(self):
        self.sitting_status = "is siting"
        
    def stand_ip(self):
        self.sitting_status = "is not siting"
    def Informations(self):
        if(self.gender == "male"):
            representative1 = "his"
        else:
            representative1 = "her"
        if(self.gender == "male"):
            representative2 = "He"
        else:
            representative2 = "She"
        print(representative1 + " name is " + self.name + " and " +  representative2 + " is " + self.personality + representative2 +" is " + self.sitting_status)

p1 = Person("John", "aggressive ", "is not siting", "male")
p2 = Person("Backy", "talkative ", "is siting", "female")

p1.Informations()
p2.Informations()
# Out:
# his name is John and He is aggressive He is is not siting
# her name is Backy and She is talkative She is is siting
# his name is John and He is aggressive He is is not siting
# her name is Backy and She is talkative She is is siting
