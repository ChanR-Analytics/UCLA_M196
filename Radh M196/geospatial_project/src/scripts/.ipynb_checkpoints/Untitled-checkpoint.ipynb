# %%
from os import getcwd, listdir, chdir 
chdir("../../..")

# %%
import numpy as np
import pandas as pd
import googlemaps
from os import getcwd, listdir
from getpass import getpass

# Getting Coordinates of Schools
coord_path = getcwd() + "/geospatial_project/data/csv"
coord_df = pd.read_csv(f"{coord_path}/{listdir(coord_path)[0]}")

coordinates = list(zip(coord_df['latitude'].tolist(), coord_df['longitude'].tolist()))

# Establishing Google Maps Client with API Key
gmaps = googlemaps.Client(key=getpass("Type in your API key: "))

# Search Restaurants Within a 10 Meter Radius from Each School
nearest_restaurant_results = []

for coord in coordinates:
    search_result = gmaps.places('restaurants', location=coord, radius=10, open_now=True)
    nearest_restaurant_results.append(search_result)


# Creating a Data Frame of Results for Each School
frame_dict_list = []
school_count = 0
while school_count < len(nearest_restaurant_results):
    names = []
    latitudes = []
    longitudes = []
    total_user_ratings = []
    ratings = []
    for i in range(len(nearest_restaurant_results[school_count]['results'])):
         name = nearest_restaurant_results[school_count]['results'][i]['name']
         latitude = nearest_restaurant_results[school_count]['results'][i]['geometry']['location']['lat']
         longitude = nearest_restaurant_results[school_count]['results'][i]['geometry']['location']['lng']
         total_user_rating = nearest_restaurant_results[school_count]['results'][i]['user_ratings_total']
         rating = nearest_restaurant_results[school_count]['results'][i]['rating']
         names.append(name)
         latitudes.append(latitude)
         longitudes.append(longitude)
         total_user_ratings.append(total_user_rating)
         ratings.append(rating)

    frame_dict = {'names': names, 'latitudes': latitudes, 'longitudes': longitudes, 'total_user_ratings': total_user_ratings, 'rating': ratings}
    frame_dict_list.append(frame_dict)
    school_count += 1


frame_list = [pd.DataFrame.from_dict(frame_dict) for frame_dict in frame_dict_list]
#AIzaSyBHWiHNgsyEL8IzkG42rcZYmqzjIXXHswE
# Out:
# Type in your API key: ········

# %%
#can you create a dictionary where the keys are the school names
#and the values are those data frames that are inside the list at the end of the code it is called frame_list
#once you have this dictionary create another dictionary where you have the keys as school names
#and values are the latitude, longitude coordinate pairs
school_results_dict = {} 

for i, school in enumerate(coord_df['school_name'].tolist()):   
    school_results_dict[school] = frame_list[i] 
school_results_dict
# Out:
# {'Granada Hills Charter High School':                                names  latitudes  longitudes  \
#  0                       Pi On Sunset  34.263962 -118.523009
#  1                      Panda Express  34.264562 -118.524779
#  2                Belgium Waffle Haus  34.264265 -118.527071
#  3                             Salata  34.264562 -118.524779
#  4   Pick Up Stix Fresh Asian Flavors  34.265152 -118.526127
#  5                        En Joy Bowl  34.265129 -118.522039
#  6        Ali Baba Persian Restaurant  34.265199 -118.515924
#  7                         Carl's Jr.  34.264518 -118.525374
#  8                           Del Taco  34.264559 -118.524169
#  9                         McDonald's  34.258823 -118.535647
#  10   Golden Hunan Chinese Restaurant  34.258261 -118.535428
#  11             Shakey's Pizza Parlor  34.258467 -118.535612
#  12                           Wendy's  34.257584 -118.537062
#  13                       Chick-fil-A  34.257561 -118.537398
#  14           Ocean Cafe & Restaurant  34.257267 -118.504612
#  15            Chipotle Mexican Grill  34.257748 -118.502082
#  16                     El Pollo Loco  34.263810 -118.502510
#  17                              IHOP  34.257844 -118.501548
#  18                          PizzaRev  34.241743 -118.535737
#  17         John's Italian Pizza Restaurant  35.718673  -79.178595
#  18                           Greek Kouzina  35.718866  -79.160501
#  19                                Hardee's  35.719860  -79.175543
#
#      total_user_ratings  rating
#  0                  322     4.1
#  1                  217     4.4
#  2                  305     4.0
#  3                  299     4.1
#  4                  340     4.4
#  5                  200     4.4
#  6                  562     4.1
#  7                  100     3.5
#  8                   89     3.4
#  9                  588     3.7
#  10                 373     4.5
#  11                 651     4.7
#  12                 618     4.6
#  13                 481     4.2
#  14                 287     4.5
#  15                 481     4.4
#  16                 310     4.4
#  17                 219     4.3
#  18                 224     4.4
#  19                 298     3.7  ,
#  'Irvine High School ':                                      names  latitudes  longitudes  \
#  0                               Spicy City  33.705821 -117.784167
#  1            Oriental Seafood Noodle House  33.705332 -117.784684
#  2                  Hokkaido Ramen Santouka  33.706773 -117.783448
#  3                            Boiling Point  33.707419 -117.782625
#  4                              Irvine cafe  33.708198 -117.781998
#  5                       Buffalo Wild Wings  33.708686 -117.782946
#  6               Sam Woo Seafood Restaurant  33.695976 -117.798353
#  7   Islands Restaurant Irvine Market Place  33.723806 -117.789176
#  8                Lazy Dog Restaurant & Bar  33.728588 -117.787979
#  9                   The Habit Burger Grill  33.704709 -117.786914
#  10             BJ's Restaurant & Brewhouse  33.729599 -117.787132
#  11                         Stonefire Grill  33.685614 -117.811343
#  12  Andrei's Conscious Cuisine & Cocktails  33.681529 -117.840481
#  13                              Rutabegorz  33.741891 -117.824670
#  14            Paul Martin’s American Grill  33.651682 -117.746638
#  15                            P.F. Chang's  33.652646 -117.745652
#  16                            Umami Burger  33.652249 -117.746517
#  17                   Cucina Enoteca Irvine  33.651721 -117.746291
#  18                  The Cheesecake Factory  33.650965 -117.746271
#  19                            North Italia  33.671761 -117.845017
#
#      total_user_ratings  rating
#  0                  116     4.0
#  1                   88     4.2
#  2                  106     4.3
#  3                  552     4.2
#  4                   15     3.8
#  5                  851     4.0
#  6                  487     4.1
#  7                  395     4.2
#  8                 1223     4.4
#  9                  514     4.5
#  10                 959     4.2
#  11                 679     4.3
#  12                 352     4.5
#  13                 560     4.5
#  14                 656     4.4
#  15                 637     4.0
#  16                 481     4.0
#  17                 563     4.4
#  18                1269     4.2
#  19                1796     4.5  }

# %%
# create another dictionary where you have
# the keys as school names
# and values are the latitude, longitude coordinate pairs
myDict2 = {}

for a,school2 in enumerate(coord_df['school_name'].tolist()):
    myDict2[school2] = coordinates[a]
myDict2
# Out:
# {'Granada Hills Charter High School': (34.260973, -118.52524650000001),
#  'Arcadia High School': (34.129807, -118.036703),
#  'Northwood High School': (35.756873799999994, -79.17389109999998),
#  'Irvine High School ': (33.7026548, -117.7815505)}

# %%
from haversine import haversine, Unit

school_frame_dict = {}
for myData,schoolName in enumerate(coord_df['school_name'].tolist()):
    school_frame_dict[schoolName] = frame_list[myData]    
#print(school_frame_dict)

lat_vals = school_frame_dict[schoolName]['latitudes'].tolist() 
long_vals = school_frame_dict[schoolName]['longitudes'].tolist() 
 
for Lat in enumerate(lat_vals):
    for Long in enumerate(long_vals):
        haversine(Lat,Long, unit='m')
print(haversine(Lat,Long, unit='m'))
# Out:
# 14769800.105435463
