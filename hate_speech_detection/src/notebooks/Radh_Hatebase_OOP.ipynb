# %% [markdown]
# # Hatebase Twitter OOP Notebook
#
# ## Contents
#
# - Import Statements
# - Class Instantiation
# - Exploratory Data Analysis Method
# - Feature Engineering Method

# %%
# Importing the HatebaseTwitter class 
from os import getcwd, listdir, chdir 
print(getcwd()) 
chdir("../python") 
from hate_speech_oop import HatebaseTwitter
# Out:
# /Users/rchatter/ChanR/UCLA_M196/hate_speech_detection/src/notebooks

# %%
# Getting the Hatebase Twitter Data 
print(getcwd()) 
chdir("../../data/HatebaseTwitter")
data_path = getcwd()
# Out:
# /Users/rchatter/ChanR/UCLA_M196/hate_speech_detection/src/python

# %%
# Instantiating the HatebaseTwitter Class 
hb = HatebaseTwitter(data_path)

# %%
# Calling the Exploratory Data Analysis Method 
hb.eda()

# %%
# Automatic Feature Engineering of TF-IDF, POS TF-IDF, and Semantic NLP Features 

## If you get an error, uncomment the code below 

# import nltk 
# nltk.download('stopwords')
# nltk.download('averaged_perceptron_tagger') 

features = hb.features()
# Out:
# /Users/rchatter/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['b', 'c', 'e', 'f', 'g', 'h', 'j', 'l', 'n', 'p', 'r', 'u', 'v', 'w'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
